# %% [markdown]
# # Distant Supervision
#
# In this notebook we will be acquiring sources of distant supervision for our models.
#
# ## WikiData Programming Languages
#
# For the Snorkel example for Chapter 5, we create a programming language extractor from the titles and bodies of Stack Overflow questions. Here we generate the file that we used by querying WikiData using SPARQL to get a list of programming languages. We then use these language names to label positive examples of programming languages in posts for training our discriminative/network extractor model.
#
# The following SPARQL query prints out the names of all [Property:31:instances of](https://www.wikidata.org/wiki/Property:P31) [Item:Q9143 programming languages](https://www.wikidata.org/wiki/Q9143) in English content from WikiData.
#
# We `SELECT DISTINCT` the item and item labels, then filter the language of the item label to English, to avoid duplicate content from other languages.

# %%
import requests

url = 'https://query.wikidata.org/sparql'
query = """
# Get all programming language names from English sources
SELECT DISTINCT ?item ?item_label
WHERE {
 # ?item wdt:P31 wd:Q9143 # instances of programming language
 ; rdfs:label ?item_label .
  
  FILTER (LANG(?item_label) = "en"). 
}

"""
r = requests.get(url, params = {'format': 'json', 'query': query})
data = r.json()

# %%
data
# Out:
# {'head': {'vars': ['item', 'item_label']},
#  'results': {'bindings': [{'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q59'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'PHP'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q251'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Java'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q810009'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'BCPL'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q812964'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'BeanShell'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q820978'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Script.NET'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q827233'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'newLISP'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q814269'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Befunge'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q377986'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Clean'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q378222'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Whitespace'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q368880'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'XL'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q369096'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Pharo'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q369244'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'SolidThinking Embed'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q375533'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Kent Recursive Calculator'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1323362'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Oberon'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1334586'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Emacs Lisp'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1356671'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'GT.M'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1359171'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'REBOL'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1335009'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Embedded SQL'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1306585'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Turbo Basic'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2117267'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Puck'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2118858'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'PureBasic'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2143563'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Uniface'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2166735'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'ALGOL 68'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2134714'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Real-time bidding'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2160963'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'PL/M'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2112198'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'PROGRES'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q383994'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'J'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q380523'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'ABAP'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q381247'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'QBasic'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2407'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'C++'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q15777'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'C'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q20479'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Agda'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q16340'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'XPath'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2370'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'C#'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q834358'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Clipper'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q830842'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'BETA'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q827773'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Verilog'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q828742'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Scilab'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1417626'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Reaktor'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1417175'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'JScript .NET'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1411658'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Gofer'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1411245'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Transact-SQL'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1411875'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'ladder logic'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q446168'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'SR'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q464338'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'EGL'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q464622'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Lustre'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q460584'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Scala'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q429801'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'BBC BASIC'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2378'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Visual Basic'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2299300'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Data Language Interface'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2321567'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'ObjectStar'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2293738'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Slate'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2347334'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'CPL'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2293187'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'xHarbour'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2298909'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Unobtrusive JavaScript'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2293248'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'FALSE'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q910482'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Oxygene'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q924660'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'WMLScript'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q943176'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Sing#'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q924737'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Interpress'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q913681'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Java Persistence Query Language'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q929932'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'GNU Data Language'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2349274'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Planner'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2357042'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Strongtalk'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2368856'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Curry'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2423764'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Physically Based Rendering Modeling Language'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2391267'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Mozart Programming System'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2384396'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'TI BASIC'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2364913'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Managed Extensions for C++'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2367280'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Superbase database'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q844595'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Bourne shell'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q840761'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'MPD'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q835139'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': '2.PAK'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q838062'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 
}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q6717920'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'MST Workshop'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q6725127'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'MacroML'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q6822228'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Met English'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q4928808'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Blue'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q4940926'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Bon'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q4943501'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Boomerang'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q4927494'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'BlooP and FlooP'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q4930559'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Bluespec, Inc.'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q4904280'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Bidule'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q4979883'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Brutus2D'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q4918681'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'BitC'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7105278'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Orwell'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7095186'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Onyx'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7118053'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'PACT'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7100142'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Orc'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7102251'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Oriel'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7118490'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'PCASTL'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7095834'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'OpenMx'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7129538'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Pan'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7120001'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'POP-11'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7139110'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Parlog'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7120003'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'POP-2'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7120399'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'PROMAL'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7121115'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'PV-Wave'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7131637'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Pantalk'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7133637'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'ParaSail'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7119550'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'PL-11'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7119581'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'PLANC'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7119636'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'PLEX'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7119554'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'PL/C'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7119633'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'PLEXIL'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7119391'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'PIKT'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7119559'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'PL360'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7119556'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'PL/P'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q5011029'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'CHAIN'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q5008638'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'CAL'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q5010978'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'CGOL'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q5012660'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'CLACL'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q5012783'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'CLP(R)'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q5005842'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'C*'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q5010234'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'CEEMAC'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q5001740'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Business Intelligence Markup Language'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7197427'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Plus'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7179822'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Pforth'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7197271'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Pipeline Pilot'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7165836'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'PeopleCode'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7191049'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'PicoLisp'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7190449'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Pic Micro Pascal'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7187965'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Php4delphi'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7191089'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Pict'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7226597'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Polymorphic Programming Language'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7226600'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Polymorphic recursion'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7265635'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Q'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7265638'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Q'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7263936'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Python for S60'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7265606'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'QUILL'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7262807'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'PyUnit'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7265978'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Qalb'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7262800'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'PyLinda'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7265605'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'QUIKTRAN'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7261054'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Pure'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7229443'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Poplog'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7248516'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Prograph'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7248484'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Programming Computable Functions'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7231352'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Portable Standard Lisp'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7246691'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'ProSet'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7248393'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Program Composition Notation'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7253904'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Psake'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7251525'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Protel'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7236198'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'PowerHouse'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7257107'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Ptolemy Project'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7248259'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Profile Scripting Language'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7248448'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Programmable Macro Language'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7277404'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'ROOP'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7301377'},
#     'item_label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Realtime Programming Language'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7275797'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'RAPID'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7268206'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Qu'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7277859'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'RTML'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7277848'},
#     'item_label': {'xml:lang': 'en', 'type': 'literal', 'value': 'RTL/2'}},
#    ...]}}

# %% [markdown]
# ## Extract the Language Labels from Nested JSON

# %%
languages = [x['item_label']['value'] for x in data['results']['bindings']]
languages[0:20]
# Out:
# ['PHP',
#  'Java',
#  'BCPL',
#  'BeanShell',
#  'Script.NET',
#  'newLISP',
#  'Befunge',
#  'Clean',
#  'Whitespace',
#  'XL',
#  'Pharo',
#  'SolidThinking Embed',
#  'Kent Recursive Calculator',
#  'Oberon',
#  'Emacs Lisp',
#  'GT.M',
#  'REBOL',
#  'Embedded SQL',
#  'Turbo Basic',
#  'Puck']

# %% [markdown]
# ## Write Languages to Disk as CSV

# %%
import csv

with open('../data/programming_languages.csv', 'w') as f:
    writer = csv.writer(f)
    for language in languages:
        writer.writerow([language])

# %% [markdown]
# ## Conclusion
#
# Now we are ready to use our programming languages in our Label Functions (LFs) in the Snorkel notebook!
