# %% [markdown]
# # Distant Supervision
#
# In this notebook we will be acquiring sources of distant supervision for our models.
#
# ## WikiData Programming Languages
#
# For the Snorkel example for Chapter 5, we create a programming language extractor from the titles and bodies of Stack Overflow questions. Here we generate the file that we used by querying WikiData using SPARQL to get a list of programming languages. We then use these language names to label positive examples of programming languages in posts for training our discriminative/network extractor model.
#
# The following SPARQL query prints out the names of all [Property:31:instances of](https://www.wikidata.org/wiki/Property:P31) [Item:Q9143 programming languages](https://www.wikidata.org/wiki/Q9143) in English content from WikiData.
#
# We `SELECT DISTINCT` the item and item labels, then filter the language of the item label to English, to avoid duplicate content from other languages.

# %%
import requests

url = 'https://query.wikidata.org/sparql'
query = """
# Get all programming language names from English sources
SELECT DISTINCT ?item ?item_label
WHERE {
 # ?item wdt:P31 wd:Q9143 # P31:instances of Q9143:programming language
 ; rdfs:label ?item_label .
  
  FILTER (LANG(?item_label) = "en"). # English only
}

"""
r = requests.get(url, params = {'format': 'json', 'query': query})
data = r.json()

# %%
import json
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "head": {
#         "vars": [
#             "item",
#             "item_label"
#         ]
#     },
#     "results": {
#         "bindings": [
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q121572"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "literal",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q169422"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "MagicPlot",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q19528"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "size",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q40612"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "intrusion detection system",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q58455"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "IBM Lotus Sametime",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4887"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Logistello",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q261595"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Windows Communication Foundation",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q170122"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "ZygoteBody",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q284319"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "ipconfig",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q257675"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "3D-Coat",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q285770"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "NetStumbler",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2317454"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Online Armor Personal Firewall",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2341591"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Zend Studio",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2207872"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "sSMTP",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2329548"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "SWFTools",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2121726"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Qnext",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2360467"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Camfrog",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2312793"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Comodo Dragon",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q6445957"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "IRIS",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q6862245"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Mimics",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q6955546"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "NTest",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q7118137"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "PALO",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q7247234"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Process",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q6872620"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Mirai",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q6055499"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Internet Explorer Developer Tools",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q6516866"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "War FTP Daemon",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q7169101"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Perl::Critic",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q5973224"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "iPer",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q7275772"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "RANCID",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q5958278"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Hyperlobby",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q6738914"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Make Compatible",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q288469"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Pound",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q305876"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "sed",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q300901"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "diff",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q508370"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Messenger Plus!",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q619133"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "xdelta",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q513561"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Auslogics Disk Defrag",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q577819"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "NetBus",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q604491"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "MikuMikuDance",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q515140"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Eigenmath",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q548225"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Anime Studio",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q533803"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "William Whitaker's Words",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2384813"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "TRNSYS",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2547971"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Gnote",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2558935"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Ashampoo Burning Studio",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2460225"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Orbit Downloader",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2381448"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "RunUO",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2389822"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "ntoskrnl.exe",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2420388"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Espresso heuristic logic minimizer",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2537534"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "WON2",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q645452"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Kerkythea",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q632851"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Microsoft Forefront Threat Management Gateway",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q644330"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Hamachi",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q639194"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "KNIME",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q650061"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "CACAO",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q970734"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Quattro Pro",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1022807"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "CANape",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1147714"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Internet Download Manager",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1147294"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Cyc",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q958204"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "MSN Explorer",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q990711"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Brosix (Company)",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1050704"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Wvdial",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q3738206"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "FaceGen",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q3567309"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Werkkzeug",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4033355"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Active-HDL",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4033115"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "AVZ",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q3614994"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "lexical analyzer",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q3829554"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "legacy code",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4032941"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "ALLPlayer",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q3627630"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Astroburn",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2980796"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Cmath",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2666056"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Saguaro",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2766509"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Corel WordPerfect Lightning",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2989407"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Local Security Authority Subsystem Service",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q3028675"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Freeplane",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2665467"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Spyware Doctor",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2890639"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "GoBack",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2743037"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "System Information for Windows",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2793053"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Google Update",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2827742"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "AiR-Boot",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2662020"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Download Accelerator Plus",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2776883"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Google Updater",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2625606"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Cheat Engine",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4048359"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Roboform",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4050161"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Sticky Password",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4051402"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Things",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4051613"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "TotalRecovery",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4051695"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Traffic Inspector",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4049634"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Small CD-Writer",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4049881"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "SpeedUpMyPC",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4048713"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "SCSI Pass-Through Direct",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4050527"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "System Mechanic",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4048209"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Returnil Virtual System",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4052425"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Unreal Commander",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q3033141"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Dmaths",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q3509033"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "O&O Defrag",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q3041960"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "DynaRoad",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q3542073"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Tunatic",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q3563900"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "VYM",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q3552754"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Disk utility",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q3273046"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "MKVToolNix",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q3100011"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "gdbserver",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q3433380"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "RivaTuner",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q3194555"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Kdesu",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4835839"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "BLADE",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4926790"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Blio",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4687887"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Aeolus",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4683976"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Acrobat Distiller",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4649926"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "AARON",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4726572"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Align-m",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4854593"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Bandicam",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4633168"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "2M",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4780802"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "AppLocale",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q4705485"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Aladdin4D",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q855971"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "RenderMan",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q840294"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Valve Hammer Editor",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q837949"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Becky!",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q860583"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Spybot \u2013 Search & Destroy",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q893155"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "boot manager",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q15991270"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "LanguageTool",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q13512473"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Tango (application)",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q11801766"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "PASS",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q16888251"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Tunnelblick",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q15063299"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "North American Release of Chrono Trigger for SNES",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q15879965"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "ORTEP",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q11695961"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "EITT",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q15063301"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Japanese Playstation Edition of Chrono Trigger",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q15917235"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Subsurface",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q11819836"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Pmap",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q11853756"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "BBBS",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q14624883"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Tresorit",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q16001882"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "AdS/CMT correspondence",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q7698864"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Tempo",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q8045324"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Xwrits",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q9251816"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "EK",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q9297196"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Metamod",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q8068467"
#                 },
# ...
#                     "type": "literal",
#                     "value": "ntpdate",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q17084877"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Spartan",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q18921415"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "The Machine",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q17020254"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Habitica",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q16928022"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "IBM Network Control Program",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q18984373"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "MyLifeOrganized",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q17064117"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "LaTeXML",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q19800969"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "SysVinit",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q19865004"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Claudico",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q18207238"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "OpenBazaar",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q5592456"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Graffiti",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q5421927"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Extension",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q5635814"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "HR",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q5641572"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Half-Life Dedicated Server",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q5530385"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Gelato",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q5418342"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Evidence Eliminator",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q5372219"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Emily Howell",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q5788503"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "CorelDRAW Graphics Suite",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q5513642"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "GLOH",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q5626452"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "G\u00f6del machine",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q5797029"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "D2dbs",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q28038508"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "image recognition",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q34336804"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "file format converter",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q30075805"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Samuel Checkers-playing Program",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q28325022"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Libratus",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q28841871"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Wikidaesthetics",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q29401885"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Skysite",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q29369805"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "HDClone",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q23680052"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Zulip",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q22988281"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Xerte",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q28833096"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Xabber",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q44860007"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "AlphaZero",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q25706819"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "DGLux5",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q30932015"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "elmo",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q42074952"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "urlwrite",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q28922520"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "DeepStack",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q43655125"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Volumio (music player)",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1427393"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "IBM Lotus Organizer",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1444688"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "SuperCalc",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1486221"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "GNU Parted",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1578279"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "WinCDEmu",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1411665"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Virtual Telecommunications Access Method",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1388631"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "FIPS",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1671530"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "PDF-XChange Viewer",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1423230"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Harvard Graphics",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1455922"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "X3D Fritz",
#                     "xml:lang": "en"
#                 }
#             }
#         ]
#     }
# }

# %% [markdown]
# ## Extract the Language Labels from nested JSON
#
# Nested JSON is a pain to work with in `DataFrames`, so we un-nest it, retaining only what we need.

# %%
languages = [
    {
        'name': x['item_label']['value'],
        'kb_url': x['item']['value'],
        'kb_id': x['item']['value'].split('/')[-1], # Get the ID
    }
    for x in data['results']['bindings']
]

# Filter out an erroneous language
languages = list(
    filter(
        lambda x: x['kb_id'] != 'Q25111344', 
        languages
    )
)

print(f'There were {len(languages):,} languages returned.\n')

for l in languages[0:10]:
    print(l)
# Out:
# There were 1,413 languages returned.
#
# {'name': 'PHP', 'kb_url': 'http://www.wikidata.org/entity/Q59', 'kb_id': 'Q59'}
# {'name': 'Java', 'kb_url': 'http://www.wikidata.org/entity/Q251', 'kb_id': 'Q251'}
# {'name': 'BCPL', 'kb_url': 'http://www.wikidata.org/entity/Q810009', 'kb_id': 'Q810009'}
# {'name': 'BeanShell', 'kb_url': 'http://www.wikidata.org/entity/Q812964', 'kb_id': 'Q812964'}
# {'name': 'Script.NET', 'kb_url': 'http://www.wikidata.org/entity/Q820978', 'kb_id': 'Q820978'}
# {'name': 'newLISP', 'kb_url': 'http://www.wikidata.org/entity/Q827233', 'kb_id': 'Q827233'}
# {'name': 'Befunge', 'kb_url': 'http://www.wikidata.org/entity/Q814269', 'kb_id': 'Q814269'}
# {'name': 'Clean', 'kb_url': 'http://www.wikidata.org/entity/Q377986', 'kb_id': 'Q377986'}
# {'name': 'Whitespace', 'kb_url': 'http://www.wikidata.org/entity/Q378222', 'kb_id': 'Q378222'}
# {'name': 'XL', 'kb_url': 'http://www.wikidata.org/entity/Q368880', 'kb_id': 'Q368880'}

# %% [markdown]
# ## Write Languages to Disk as CSV

# %%
import jsonlines

with jsonlines.open('../data/programming_languages.jsonl', mode='w') as writer:
    writer.write_all(languages)

# %% [markdown]
# ## Now get a list of operating systems to create negative LFs from

# %%
import requests

url = 'https://query.wikidata.org/sparql'
query = """
# Get all operating system names from English sources
SELECT DISTINCT ?item ?item_label
WHERE {
 # ?item wdt:P31 wd:Q9135 # instances of programming language
 ; rdfs:label ?item_label .
  
  FILTER (LANG(?item_label) = "en"). 
}

"""
r = requests.get(url, params = {'format': 'json', 'query': query})
data = r.json()

# %%
programs = [
    {
        'name': x['item_label']['value'],
        'kb_url': x['item']['value'],
        'kb_id': x['item']['value'].split('/')[-1], # Get the ID
    }
    for x in data['results']['bindings']
]

print(f'There were {len(programs):,} programs returned.\n')

for l in programs[0:10]:
    print(l)
# Out:
# There were 967 programs returned.
#
# {'name': 'Microsoft Windows', 'kb_url': 'http://www.wikidata.org/entity/Q1406', 'kb_id': 'Q1406'}
# {'name': 'Windows 8', 'kb_url': 'http://www.wikidata.org/entity/Q5046', 'kb_id': 'Q5046'}
# {'name': 'Apple DOS', 'kb_url': 'http://www.wikidata.org/entity/Q621234', 'kb_id': 'Q621234'}
# {'name': 'IRIX', 'kb_url': 'http://www.wikidata.org/entity/Q627611', 'kb_id': 'Q627611'}
# {'name': 'Apple ProDOS', 'kb_url': 'http://www.wikidata.org/entity/Q621328', 'kb_id': 'Q621328'}
# {'name': 'Apple CP/M', 'kb_url': 'http://www.wikidata.org/entity/Q621220', 'kb_id': 'Q621220'}
# {'name': 'MUSIC/SP', 'kb_url': 'http://www.wikidata.org/entity/Q629795', 'kb_id': 'Q629795'}
# {'name': 'UNIX System V', 'kb_url': 'http://www.wikidata.org/entity/Q633192', 'kb_id': 'Q633192'}
# {'name': 'Novell Open Enterprise Server', 'kb_url': 'http://www.wikidata.org/entity/Q1197839', 'kb_id': 'Q1197839'}
# {'name': 'SunOS', 'kb_url': 'http://www.wikidata.org/entity/Q1208460', 'kb_id': 'Q1208460'}

# %%
import jsonlines

with jsonlines.open('../data/operating_systems.jsonl', mode='w') as writer:
    writer.write_all(programs)

# %% [markdown]
# ## Conclusion
#
# Now we are ready to use our programming languages in our Label Functions (LFs) in the Snorkel notebook!
