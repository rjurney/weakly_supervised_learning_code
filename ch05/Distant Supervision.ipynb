# %% [markdown]
# # Distant Supervision
#
# In this notebook we will be acquiring sources of distant supervision for our models.
#
# ## WikiData Programming Languages
#
# For the Snorkel example for Chapter 5, we create a programming language extractor from the titles and bodies of Stack Overflow questions. Here we generate the file that we used by querying WikiData using SPARQL to get a list of programming languages. We then use these language names to label positive examples of programming languages in posts for training our discriminative/network extractor model.
#
# The following SPARQL query prints out the names of all [Property:31:instances of](https://www.wikidata.org/wiki/Property:P31) [Item:Q9143 programming languages](https://www.wikidata.org/wiki/Q9143) in English content from WikiData.
#
# We `SELECT DISTINCT` the item and item labels, then filter the language of the item label to English, to avoid duplicate content from other languages.

# %%
import requests

url = 'https://query.wikidata.org/sparql'
query = """
# Get all programming language names from English sources
SELECT DISTINCT ?item ?item_label
WHERE {
 # ?item wdt:P31 wd:Q9143 # instances of programming language
 ; rdfs:label ?item_label .
  
  FILTER (LANG(?item_label) = "en"). 
}

"""
r = requests.get(url, params = {'format': 'json', 'query': query})
data = r.json()

# %%
import json
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "head": {
#         "vars": [
#             "item",
#             "item_label"
#         ]
#     },
#     "results": {
#         "bindings": [
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q59"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "PHP",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q251"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Java",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q810009"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "BCPL",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q812964"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "BeanShell",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q820978"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Script.NET",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q827233"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "newLISP",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q814269"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Befunge",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q377986"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Clean",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q378222"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Whitespace",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q368880"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "XL",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q369096"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Pharo",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q369244"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "SolidThinking Embed",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q375533"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Kent Recursive Calculator",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1323362"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Oberon",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1334586"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Emacs Lisp",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1356671"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "GT.M",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1359171"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "REBOL",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1335009"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Embedded SQL",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1306585"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Turbo Basic",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q383994"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "J",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q380523"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "ABAP",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q381247"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "QBasic",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q848460"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Portlet",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q849146"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Common Lisp",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q848317"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Nullsoft Scriptable Install System",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1417626"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Reaktor",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1417175"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "JScript .NET",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1411658"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Gofer",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1411245"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Transact-SQL",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1411875"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "ladder logic",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q28865"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Python",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2349274"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Planner",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2357042"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Strongtalk",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2368856"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Curry",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2423764"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Physically Based Rendering Modeling Language",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2391267"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Mozart Programming System",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2384396"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "TI BASIC",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2364913"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Managed Extensions for C++",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2367280"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Superbase database",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2117267"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Puck",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2118858"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "PureBasic",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2143563"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Uniface",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2166735"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "ALGOL 68",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2134714"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Real-time bidding",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2160963"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "PL/M",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q2112198"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "PROGRES",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1439015"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Fortress",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1418686"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Sieve",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1427296"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Steel Bank Common Lisp",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1427564"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Flavors",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1457000"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Metafont",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1443431"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Objective-J",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q446168"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "SR",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q464338"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "EGL",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q464622"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Lustre",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q460584"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Scala",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q429801"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "BBC BASIC",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1537488"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "M",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1566023"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Rocky Mountain BASIC",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1549370"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Aldor",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1547448"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "TECO",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q1547213"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "OpenGL ES Shading Language",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q

#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Kaya",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q25344700"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Disk Extended Color BASIC",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q25345930"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Citrine",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q25345888"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Qore",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q25395189"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "LTR",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q25384242"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "RCML",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q25385679"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "CSS preprocessor",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q25379932"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Neo Sign 0f Misery",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q25461692"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "SuperNova",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q28046771"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Milk",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q28126925"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "CS-4",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q27967355"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "WaveGL",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q27578833"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "TouchDesigner",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q28038707"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Posity",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q26898104"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "EXAPT",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q27961782"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "Cuis Smalltalk",
#                     "xml:lang": "en"
#                 }
#             },
#             {
#                 "item": {
#                     "type": "uri",
#                     "value": "http://www.wikidata.org/entity/Q28136610"
#                 },
#                 "item_label": {
#                     "type": "literal",
#                     "value": "EarSketch",
#                     "xml:lang": "en"
#                 }
#             }
#         ]
#     }
# }

# %% [markdown]
# ## Extract the Language Labels from nested JSON
#
# Nested JSON is a pain to work with in `DataFrames`, so we un-nest it, retaining only what we need.

# %%
languages = [
    {
        'name': x['item_label']['value'],
        'kb_url': x['item']['value'],
        'kb_id': x['item']['value'].split('/')[-1], # Get the ID
    }
    for x in data['results']['bindings']
]

# Filter out an erroneous language
languages = list(
    filter(
        lambda x: x['kb_id'] != 'Q25111344', 
        languages
    )
)

print(f'There were {len(languages):,} languages returned.\n')

for l in languages[0:10]:
    print(l)
# Out:
# There were 1,413 languages returned.
#
# {'name': 'PHP', 'kb_url': 'http://www.wikidata.org/entity/Q59', 'kb_id': 'Q59'}
# {'name': 'Java', 'kb_url': 'http://www.wikidata.org/entity/Q251', 'kb_id': 'Q251'}
# {'name': 'BCPL', 'kb_url': 'http://www.wikidata.org/entity/Q810009', 'kb_id': 'Q810009'}
# {'name': 'BeanShell', 'kb_url': 'http://www.wikidata.org/entity/Q812964', 'kb_id': 'Q812964'}
# {'name': 'Script.NET', 'kb_url': 'http://www.wikidata.org/entity/Q820978', 'kb_id': 'Q820978'}
# {'name': 'newLISP', 'kb_url': 'http://www.wikidata.org/entity/Q827233', 'kb_id': 'Q827233'}
# {'name': 'Befunge', 'kb_url': 'http://www.wikidata.org/entity/Q814269', 'kb_id': 'Q814269'}
# {'name': 'Clean', 'kb_url': 'http://www.wikidata.org/entity/Q377986', 'kb_id': 'Q377986'}
# {'name': 'Whitespace', 'kb_url': 'http://www.wikidata.org/entity/Q378222', 'kb_id': 'Q378222'}
# {'name': 'XL', 'kb_url': 'http://www.wikidata.org/entity/Q368880', 'kb_id': 'Q368880'}

# %% [markdown]
# ## Write Languages to Disk as CSV

# %%
import jsonlines

with jsonlines.open('../data/programming_languages.jsonl', mode='w') as writer:
    writer.write_all(languages)

# %% [markdown]
# ## Conclusion
#
# Now we are ready to use our programming languages in our Label Functions (LFs) in the Snorkel notebook!
